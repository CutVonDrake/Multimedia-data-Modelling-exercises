# %% [markdown]
# Random(I,t): compute and show bit panels of a random patch (positions and sizes) of I if t is even, otherwise
# show in half image the red channel and in the remaining part the blue channel (you can choose any fixed
# configuration of "half image" (high, low) (left,right), etc.).

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
img = cv2.imread(r"C:\Users\andre\Pictures\211712.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
print(img.shape)
nx=random.randint(0,img.shape[0])
ny=random.randint(0,img.shape[1])
x=random.randint(0,img.shape[0]-nx)
y=random.randint(0,img.shape[1]-ny)

img2=img[x:x+n,y:y+n,:].copy()
plt.imshow(img2)
binarize = np.vectorize(lambda x: format(x, 'b').zfill(8))(img2)
print(binarize)
# Out:
# (579, 1000, 3)
# [[['10000111' '10000001' '01100111']
#   ['10000100' '10000000' '01100101']
#   ['10000101' '10000001' '01100110']
#   ...
#   ['11011000' '11010000' '10111101']
#   ['11001001' '11000001' '10101100']
#   ['11001111' '11000100' '10101110']]
#
#  [['10001011' '10000101' '01101101']
#   ['10001001' '10000101' '01101100']
#   ['10001010' '10000110' '01101101']
#   ...
#   ['11010101' '11001101' '10111010']
#   ['11001100' '11000100' '10101111']
#   ['11010010' '11000111' '10110001']]
#
#  [['10001100' '10000110' '01101110']
#   ['10001010' '10000110' '01101101']
#   ['10001100' '10001000' '01101111']
#   ...
#   ['11010000' '11001000' '10110101']
#   ['11000111' '10111111' '10101010']
#   ['11010001' '11000110' '10110000']]
#
#  ...
#
#  [['00100100' '00100111' '00010010']
#   ['00100100' '00100111' '00010100']
#   ['00011100' '00011111' '00001110']
#   ...
#   ['10000100' '01111001' '00111011']
#   ['10000011' '01110110' '01000001']
#   ['01111110' '01101101' '01010011']]
#
#  [['00101101' '00110000' '00011011']
#   ['00100010' '00100101' '00010010']
#   ['00011100' '00011111' '00001110']
#   ...
#   ['01110100' '01100110' '00110101']
#   ['10000011' '01110100' '01001011']
#   ['10001010' '01111011' '01010100']]
#
#  [['00110100' '00110111' '00100010']
#   ['00101101' '00110000' '00011101']
#   ['00101000' '00101011' '00011010']
#   ...
#   ['10000001' '01110011' '01000010']
#   ['10001000' '01111001' '01010000']
#   ['01111010' '01101011' '01000100']]]

# %%
# Out:
# 579

# %%
bin
