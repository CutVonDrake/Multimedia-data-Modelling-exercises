# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread(r'C:\Users\andre\Desktop\Multimedia images\cat.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis('on')  # Nascondi gli assi
plt.show()


array=img_rgb.copy()
array2=img_rgb.copy()
print(array.shape)
# Out:
# (715, 474, 3)

# %%
for x in range(3):
# Out:
# array([[16, 12, 11],
#        [16, 12, 11],
#        [16, 12, 11],
#        ...,
#        [97, 87, 75],
#        [97, 87, 75],
#        [97, 87, 75]], dtype=uint8)

# %%
np.zeros 
A= array[... , 1]+array[..., 2]
B=array[0]+array[2]
C= array[0]+array[1]

# %%
print(A)
# Out:
# [[133  91  88]
#  [133  91  88]
#  [133  91  88]
#  ...
#  [  5 171  75]
#  [  5 171  75]
#  [  5 171  75]]

# %%
plt.imshow(A, cmap="gray")
plt.axis('on')  # Nascondi gli assi
plt.show()

# %%
w=array.shape[0]
h=array.shape[1]

APred= np.zeros((w,h), dtype=array.dtype)
APgreen= np.zeros((w,h), dtype=array.dtype)
APblue= np.zeros((w,h), dtype=array.dtype)


C=array[... , 1]+array[..., 2]
M= array[... , 0]+array[..., 2]
Y= array[... , 1]+array[..., 0]

# %%
plt.imshow(Y, cmap="gray")
plt.axis('on')  # Nascondi gli assi
plt.show()

# %%
M= np.array([[0.299, 0.587, 0.114], [0.596, -0.275 ,-0.321], [0.212, -0.523, 0.311]])

# %%
print(M)
# Out:
# [[ 0.299  0.587  0.114]
#  [ 0.596 -0.275 -0.321]
#  [ 0.212 -0.523  0.311]]

# %%
print(M@M)
# Out:
# [[ 0.463421 -0.045534 -0.118887]
#  [-0.053748  0.59336   0.056388]
#  [-0.182388  0.105616  0.288772]]

# %%
print(array[1,1,:])
# Out:
# [16 12 11]

# %%
array2 = array2.astype(np.float32)

for x in range(w):
    for y in range(h):
        array2[x,y,:]=array[x,y,:]@M

plt.imshow(array2[...,0], cmap='gray')
plt.axis('on')  # Nascondi gli assi
plt.show()

# %%
plt.imshow(array2[...,1], cmap='gray')
plt.axis('on')  # Nascondi gli assi
plt.show()

# %%
plt.imshow(array2[...,2], cmap='gray')
plt.axis('on')  # Nascondi gli assi
plt.show()

# %%
A=np.array([1,1,1])

# %%
A@M
# Out:
# array([ 1.107, -0.211,  0.104])
